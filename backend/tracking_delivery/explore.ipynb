# %%
import requests
import sqlite3

# %%
db_path = r"C:\Users\Karim\Projects\scraping_prices\data\competitors.db"

# %%
conn = sqlite3.connect(db_path)
cur = conn.cursor()
cur.execute('select * from scrape_runs')
rows = cur.fetchall()
conn.close()

# %%
for row in rows:
    print(row)
# Out:
# (1, 1, '2026-09-18 07:52:08', 2399.0, 'success', 200, 1, None)
# (2, 2, '2026-09-18 07:52:09', 3369.0, 'success', 200, 1, None)
# (3, 3, '2026-09-18 07:52:09', 2099.0, 'success', 200, 1, None)
# (4, 4, '2026-09-18 07:52:10', 1379.0, 'success', 200, 1, None)
# (5, 5, '2026-09-18 07:52:10', 1499.0, 'success', 200, 1, None)
# (6, 6, '2026-09-18 07:52:11', 879.0, 'success', 200, 1, None)
# (7, 7, '2026-09-18 07:52:11', 1149.0, 'success', 200, 1, None)
# (8, 8, '2026-09-18 07:52:12', 1999.0, 'success', 200, 1, None)
# (9, 9, '2026-09-18 07:52:13', 2479.0, 'success', 200, 1, None)
# (10, 10, '2026-09-18 07:52:13', 3129.0, 'success', 200, 1, None)
# (11, 11, '2026-09-18 07:52:14', 1749.0, 'success', 200, 1, None)
# (12, 12, '2026-09-18 07:52:22', 998.0, 'success', 200, 1, None)
# (13, 13, '2026-09-18 07:52:30', 1295.0, 'success', 200, 1, None)
# (14, 14, '2026-09-18 07:52:40', 3050.0, 'success', 200, 1, None)
# (15, 15, '2026-09-18 07:52:51', 2029.0, 'success', 200, 1, None)
# ...

# %%
l = ["dwa", "dwad", "ss"]
s = tuple(l)
print(str(s))
# Out:
# ('dwa', 'dwad', 'ss')
